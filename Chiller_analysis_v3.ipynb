# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.dates as mdates
from matplotlib.dates import DateFormatter
from matplotlib import dates
import seaborn as sns
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Import Data overview

# %%
df = pd.read_csv('data_dump.csv')
df.head()
# Out:
#              timestamp  CHWP-004Power_Factor  CHWP-004Speed_SP  CHWP-004KWh
# 0  2019-08-22 11:45:00                   NaN               NaN          NaN  \
# 1  2019-08-22 12:15:00                   NaN               NaN          NaN
# 2  2019-08-22 12:30:00                   NaN               NaN          NaN
# 3  2019-08-22 12:45:00                   NaN               NaN          NaN
# 4  2019-08-22 13:00:00                   NaN               NaN          NaN
#
#    CHWP-004Speed_Meter  CHWP-004Override_Enable  CHWP-004Running_Hours
# 0                  NaN                      NaN                    NaN  \
# 1                  NaN                      NaN                    NaN
# 2                  NaN                      NaN                    NaN
# 3                  NaN                      NaN                    NaN
# 4                  NaN                      NaN                    NaN
#
#    CHWP-004Speed_Override_SP  CHWP-004VSD_Speed_Feedback
# 0                        NaN                         NaN  \
# 1                        NaN                         NaN
# 2                        NaN                         NaN
# 3                        NaN                         NaN
# 4                        NaN                         NaN
#
#    CHWP-004Remote_Control-1  CHWP-004Master_Trip_Alarm
# 0                       NaN                        NaN  \
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#    CHWP-004VSD_Speed_Control  CHWP-004Seq  CHWP-004Override_ON_OFF
# 0                        NaN          NaN                      NaN  \
# 1                        NaN          NaN                      NaN
# 2                        NaN          NaN                      NaN
# 3                        NaN          NaN                      NaN
# 4                        NaN          NaN                      NaN
#
#    CHWP-004Local_Remote_Status  CHWP-004KVA  CHWP-004Running_Status
# 0                          NaN          NaN                     NaN  \
# 1                          NaN          NaN                     NaN
# 2                          NaN          NaN                     NaN
# 3                          NaN          NaN                     NaN
# 4                          NaN          NaN                     NaN
#
#    CHWP-004Remote_Control-2  CHWP-004Speed_Override_Enable
# 0                       NaN                            NaN  \
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
#
#    CHWP-004Start_Stop_Control  CHWP-004Enable  CHWP-004KW
# 0                         NaN             NaN         NaN  \
# 1                         NaN             NaN         NaN
# 2                         NaN             NaN         NaN
# 3                         NaN             NaN         NaN
# 4                         NaN             NaN         NaN
#
#    CHWP-004Drivers.BacnetNetwork.New Chiller Plant.points.CHWP-004 Diff. Pressure
# 0                                                NaN                               \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    CHWP-004Diff_Pressure  CHWP-004on  ACPC-4Active_Chilled_Water_Setpoint
# 0                    NaN         NaN                                  NaN  \
# 1                    NaN         NaN                                  NaN
# 2                    NaN         NaN                                  NaN
# 3                    NaN         NaN                                  NaN
# 4                    NaN         NaN                             7.429999
#
#    ACPC-4Average_Input_Current_AFD_1A  ACPC-4Evap_Approach_ckt1
# 0                                 NaN                       NaN  \
# 1                                 NaN                       NaN
# 2                                 NaN                       NaN
# 3                                 NaN                       NaN
# 4                                 0.0                       NaN
#
#    ACPC-4Running_Status  ACPC-4Cond_Sat_Ref_Temperature_Ckt1
# 0                   NaN                                  NaN  \
# 1                   NaN                                  NaN
# 2                   NaN                                  NaN
# 3                   NaN                                  NaN
# 4                   NaN                              34.9235
#
#    ACPC-4Chilled_Water_Setpoint  ACPC-4Cond_Sat_Ref_Temperature_Ckt2
# 0                           NaN                                  NaN  \
# 1                           NaN                                  NaN
# 2                           NaN                                  NaN
# 3                           NaN                                  NaN
# 4                      7.429999                            35.345154
#
#    ACPC-4CHWS_Temp  ACPC-4Evap_Sat_Ref_Temperature_Ckt1
# 0              NaN                                  NaN  \
# 1              NaN                                  NaN
# 2              NaN                                  NaN
# 3              NaN                                  NaN
# 4              NaN                            20.962826
#
#    ACPC-4Diff_Ref_Pressure_Ckt1  ACPC-4Outdoor_Air_Temperature
# 0                           NaN                            NaN  \
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                    295.700012                      34.470001
#
#    ACPC-4Valve_Remote_Control-1  ACPC-4Local_Remote_Start
# 0                           NaN                       NaN  \
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#    ACPC-4Chiller_Loading_Percent  ACPC-4Evaporator_Leaving_Water_Temperature
# 0                            NaN                                         NaN  \
# 1                            NaN                                         NaN
# 2                            NaN                                         NaN
# 3                            NaN                                         NaN
# 4                            0.0                                   20.700001
#
#    ACPC-4Running_Hours  ACPC-4efficiency  ACPC-4Discharge_Temperature_Cprsr2A
# 0                  NaN               NaN                                  NaN  \
# 1                  NaN               NaN                                  NaN
# 2                  NaN               NaN                                  NaN
# 3                  NaN               NaN                                  NaN
# 4                  NaN               NaN                            37.240002
#
#    ACPC-4Winding_Temp_#1_Motor_2A  ACPC-4Power_Factor
# 0                             NaN                 NaN  \
# 1                             NaN                 NaN
# 2                             NaN                 NaN
# 3                             NaN                 NaN
# 4                       35.209999                 NaN
#
#    ACPC-4Percent_Speed_Cprsr1A  ACPC-4Average_Motor_Current_%_RLA_AFD_2A
# 0                          NaN                                       NaN  \
# 1                          NaN                                       NaN
# 2                          NaN                                       NaN
# 3                          NaN                                       NaN
# 4                          0.0                                       0.0
#
#    ACPC-4Winding_Temp_#1_Motor_1A  ACPC-4Cond_Sat_Ref_Pressure_Ckt1
# 0                             NaN                               NaN  \
# 1                             NaN                               NaN
# 2                             NaN                               NaN
# 3                             NaN                               NaN
# 4                       34.740002                        886.099976
#
#    ACPC-4Remote_Control-1  ACPC-4CHW_Temp_Diff
# 0                     NaN                  NaN  \
# 1                     NaN                  NaN
# 2                     NaN                  NaN
# 3                     NaN                  NaN
# 4                     NaN                  NaN
#
#    ACPC-4Discharge_Temperature_Cprsr1A
# 0                                  NaN  \
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                            36.830002
#
#    ACPC-4Average_Motor_Current_%_RLA_AFD_1A  ACPC-4Valve_Remote_Control-2
# 0                                       NaN                           NaN  \
# 1                                       NaN                           NaN
# 2                                       NaN                           NaN
# 3                                       NaN                           NaN
# 4                                       0.0                           NaN
#
#    ACPC-4Air_Flow_Ckt2  ACPC-4Air_Flow_Ckt1  ACPC-4Demand_Limit_Setpoint
# 0                  NaN                  NaN                          NaN  \
# 1                  NaN                  NaN                          NaN
# 2                  NaN                  NaN                          NaN
# 3                  NaN                  NaN                          NaN
# 4                  0.0                  0.0                          0.0
#
#    ACPC-4Oil_Pressure_Comp2A  ACPC-4Evaporator_Water_Flow  ACPC-4Flow_Rate
# 0                        NaN                          NaN              NaN  \
# 1                        NaN                          NaN              NaN
# 2                        NaN                          NaN              NaN
# 3                        NaN                          NaN              NaN
# 4                 588.599976                          0.0              NaN
#
#    ACPC-4Override_Enable  ACPC-4Winding_Temp_#2_Motor_2A
# 0                    NaN                             NaN  \
# 1                    NaN                             NaN
# 2                    NaN                             NaN
# 3                    NaN                             NaN
# 4                    NaN                       36.700001
#
#    ACPC-4Chilled_Water_Setpoint1  ACPC-4MOV_Open_Control
# 0                            NaN                     NaN  \
# 1                            NaN                     NaN
# 2                            NaN                     NaN
# 3                            NaN                     NaN
# 4                       7.429999                     NaN
#
#    ACPC-4Active_Chilled_Water_Setpoint1  ACPC-4Valve_Override_ON_OFF
# 0                                   NaN                          NaN  \
# 1                                   NaN                          NaN
# 2                                   NaN                          NaN
# 3                                   NaN                          NaN
# 4                              7.429999                          NaN
#
#    ACPC-4Evap_Approach_ckt2  ACPC-4Valve_Override_Enable
# 0                       NaN                          NaN  \
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    ACPC-4Start_Stop_Control  ACPC-4Evaporator_Entering_Water_Temperature
# 0                       NaN                                          NaN  \
# 1                       NaN                                          NaN
# 2                       NaN                                          NaN
# 3                       NaN                                          NaN
# 4                       NaN                                        34.98
#
#    ACPC-4Oil_Pressure_Comp1A  ACPC-4Average_Input_Current_AFD_2A
# 0                        NaN                                 NaN  \
# 1                        NaN                                 NaN
# 2                        NaN                                 NaN
# 3                        NaN                                 NaN
# 4                 596.099976                                 0.0
#
#    ACPC-4Evap_Ref_Pressure_Ckt1  ACPC-4Master_Trip_Alarm  ACPC-4KWh
# 0                           NaN                      NaN        NaN  \
# 1                           NaN                      NaN        NaN
# 2                           NaN                      NaN        NaN
# 3                           NaN                      NaN        NaN
# 4                    590.400024                      NaN        NaN
#
#    ACPC-4Remote_Control-2  ACPC-4Cooling_Load
# 0                     NaN                 NaN  \
# 1                     NaN                 NaN
# 2                     NaN                 NaN
# 3                     NaN                 NaN
# 4                     NaN                 NaN
#
#    ACPC-4Evap_Sat_Ref_Temperature_Ckt2  ACPC-4Active_Demand_Limit_Setpoint
# 0                                  NaN                                 NaN  \
# 1                                  NaN                                 NaN
# 2                                  NaN                                 NaN
# 3                                  NaN                                 NaN
# 4                             20.88986                               200.0
#
#    ACPC-4Seq  ACPC-4Percent_Speed_Cprsr2A  ACPC-4Evap_Ref_Pressure_Ckt2
# 0        NaN                          NaN                           NaN  \
# 1        NaN                          NaN                           NaN
# 2        NaN                          NaN                           NaN
# 3        NaN                          NaN                           NaN
# 4        NaN                          0.0                    589.099976
#
#    ACPC-4KVA  ACPC-4Cond_Sat_Ref_Pressure_Ckt2  ACPC-4Diff_Ref_Pressure_Ckt2
# 0        NaN                               NaN                           NaN  \
# 1        NaN                               NaN                           NaN
# 2        NaN                               NaN                           NaN
# 3        NaN                               NaN                           NaN
# 4        NaN                             896.0                    306.899994
#
#    ACPC-4Temp_Reset  ACPC-4Override_ON_OFF  ACPC-4CHWR_Temp  ACPC-4on
# 0               NaN                    NaN              NaN       NaN  \
# 1               NaN                    NaN              NaN       NaN
# 2               NaN                    NaN              NaN       NaN
# 3               NaN                    NaN              NaN       NaN
# 4               NaN                    NaN              NaN       NaN
#
#    ACPC-4MOV_Oper_Status  ACPC-4MOV_CLose_Status
# 0                    NaN                     NaN  \
# 1                    NaN                     NaN
# 2                    NaN                     NaN
# 3                    NaN                     NaN
# 4                    NaN                     NaN
#
#    ACPC-4Winding_Temp_#2_Motor_1A  ACPC-4ACC04_ACPC-4 EM.points.Flow
# 0                             NaN                                NaN  \
# 1                             NaN                                NaN
# 2                             NaN                                NaN
# 3                             NaN                                NaN
# 4                           33.82                                NaN
#
#    ACPC-4ACC04_ACPC-4 EM.points.Energy(unsigned)
# 0                                            NaN  \
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Average Input Voltage AFD 1A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current W AFD 1A
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current W % RLA AFD 2A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current V AFD 1A
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Voltage UV AFD 2A
# 0                                                NaN                  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current V % RLA AFD 2A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Enable  ACPC-4Comp_Power  ACPC-4ACC04_ACPC-4 EM.points.Inlet temp.
# 0           NaN               NaN                                       NaN  \
# 1           NaN               NaN                                       NaN
# 2           NaN               NaN                                       NaN
# 3           NaN               NaN                                       NaN
# 4           NaN               NaN                                       NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Transistor Temperature AFD 1A
# 0                                                NaN                        \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.DC Bus Voltage AFD 1A
# 0                                                NaN                \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Voltage UV AFD 1A
# 0                                                NaN                  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4ACC04_ACPC-4 EM.points.Exit temp.
# 0                                      NaN  \
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Average Motor Voltage AFD 1A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Inverter Base Temperature AFD 1A
# 0                                                NaN                           \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current U % RLA AFD 2A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current W % RLA AFD 1A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Run Time Cprsr2A
# 0                                                NaN           \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Voltage VW AFD 2A
# 0                                                NaN                  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current U % RLA AFD 1A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Transistor Temperature AFD 2A
# 0                                                NaN                        \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Stator Frequency AFD 2A
# 0                                                NaN                  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Average Input Voltage AFD 2A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.DC Bus Voltage AFD 2A
# 0                                                NaN                \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Output Power AFD 2A
# 0                                                NaN              \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current V AFD 2A
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Starts Cprsr1A
# 0                                                NaN         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Input Power AFD 2A
# 0                                                NaN             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Rectifier Base Temperature AFD 2A
# 0                                                NaN                            \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Estimated Input Frequency AFD 2A
# 0                                                NaN                           \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Voltage VW AFD 1A
# 0                                                NaN                  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Estimated Input Frequency AFD 1A
# 0                                                NaN                           \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Run Time Cprsr1A
# 0                                                NaN           \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Voltage WU AFD 1A
# 0                                                NaN                  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current U AFD 2A
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Starts Cprsr2A
# 0                                                NaN         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current V % RLA AFD 1A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Output Power AFD 1A
# 0                                                NaN              \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Voltage WU AFD 2A
# 0                                                NaN                  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current W AFD 2A
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Rectifier Base Temperature AFD 1A
# 0                                                NaN                            \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Motor Current U AFD 1A
# 0                                                NaN                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Average Motor Voltage AFD 2A
# 0                                                NaN                       \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Input Power AFD 1A
# 0                                                NaN             \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Stator Frequency AFD 1A
# 0                                                NaN                  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-4Drivers.BacnetNetwork.ACPC-4.points.Inverter Base Temperature AFD 2A
# 0                                                NaN                           \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    ACPC-1CHWS_Temp  ACPC-1Temp_Reset
# 0              NaN               NaN  \
# 1              NaN               NaN
# 2              NaN               NaN
# 3              NaN               NaN
# 4              NaN               NaN
#
#    ACPC-1Average_Motor_Current_%_RLA_AFD_1A  ACPC-1Chilled_Water_Setpoint
# 0                                 82.699997                      7.325000  \
# 1                                 82.599998                      7.250000
# 2                                 82.300003                      7.255002
# 3                                  0.000000                      7.440000
# 4                                  0.000000                      7.429999
#
#    ACPC-1Average_Input_Current_AFD_2A  ACPC-1Discharge_Temperature_Cprsr2A
# 0                           59.099998                                  NaN  \
# 1                           62.700001                            55.529999
# 2                           63.000000                            55.500000
# 3                            0.000000                            53.209999
# 4                            0.000000                            49.049999
#
#    ACPC-1Comp_Power  ACPC-1MOV_Oper_Status  ACPC-1Valve_Remote_Control-2
# 0               NaN                    NaN                           NaN  \
# 1               NaN                    NaN                           NaN
# 2               NaN                    NaN                           NaN
# 3               NaN                    NaN                           NaN
# 4               NaN                    NaN                           NaN
#
#    ACPC-1MOV_Open_Control  ACPC-1Air_Flow_Ckt1  ACPC-1CHWR_Temp
# 0                     NaN            48.360676              NaN  \
# 1                     NaN            48.852493              NaN
# 2                     NaN            48.886307              NaN
# 3                     NaN             0.000000              NaN
# 4                     NaN             0.000000              NaN
#
#    ACPC-1Air_Flow_Ckt2  ACPC-1Chilled_Water_Setpoint1  ACPC-1KVA
# 0            64.588509                       7.325000        NaN  \
# 1            66.652565                       7.250000        NaN
# 2            63.980301                       7.255002        NaN
# 3             0.000000                       7.440000        NaN
# 4             0.000000                       7.429999        NaN
#
#    ACPC-1Local_Remote_Start  ACPC-1Winding_Temp_#2_Motor_1A
# 0                       NaN                             NaN  \
# 1                       NaN                             NaN
# 2                       NaN                             NaN
# 3                       NaN                             NaN
# 4                       NaN                             NaN
#
#    ACPC-1Discharge_Temperature_Cprsr1A
# 0                                  NaN  \
# 1                            57.410000
# 2                            57.299999
# 3                            54.669998
# 4                            50.240002
#
#    ACPC-1Evaporator_Leaving_Water_Temperature  ACPC-1Percent_Speed_Cprsr1A
# 0                                         NaN                          NaN  \
# 1                                        7.19                    58.165215
# 2                                        7.12                    58.674877
# 3                                       10.94                     0.000000
# 4                                       13.73                     0.000000
#
#    ACPC-1Oil_Pressure_Comp2A  ACPC-1Valve_Override_ON_OFF  ACPC-1Flow_Rate
# 0                        NaN                          NaN              NaN  \
# 1                1221.900024                          NaN              NaN
# 2                1223.900024                          NaN              NaN
# 3                 424.600006                          NaN              NaN
# 4                 467.100006                          NaN              NaN
#
#    ACPC-1Cond_Sat_Ref_Temperature_Ckt1  ACPC-1Winding_Temp_#1_Motor_1A
# 0                                  NaN                             NaN  \
# 1                            48.563164                       33.779999
# 2                            48.366821                       33.200001
# 3                            38.717606                       30.610001
# 4                            37.215229                       21.260000
#
#    ACPC-1Running_Status  ACPC-1on  ACPC-1Remote_Control-1
# 0                   NaN       NaN                     NaN  \
# 1                   NaN       NaN                     NaN
# 2                   NaN       NaN                     NaN
# 3                   NaN       NaN                     NaN
# 4                   NaN       NaN                     NaN
#
#    ACPC-1Evaporator_Water_Flow  ACPC-1Percent_Speed_Cprsr2A
# 0                          NaN                          NaN  \
# 1                          NaN                    58.271397
# 2                          NaN                    58.717350
# 3                          NaN                     0.000000
# 4                          1.0                     0.000000
#
#    ACPC-1Running_Hours  ACPC-1Power_Factor  ACPC-1Valve_Remote_Control-1
# 0                  NaN                 NaN                           NaN  \
# 1                  NaN                 NaN                           NaN
# 2                  NaN                 NaN                           NaN
# 3                  NaN                 NaN                           NaN
# 4                  NaN                 NaN                           NaN
#
#    ACPC-1Demand_Limit_Setpoint  ACPC-1KWh
# 0                          NaN        NaN  \
# 1                          0.0        NaN
# 2                          0.0        NaN
# 3                          0.0        NaN
# 4                          0.0        NaN
#
#    ACPC-1Evap_Sat_Ref_Temperature_Ckt1  ACPC-1Cooling_Load  ACPC-1Seq
# 0                                  NaN                 NaN        NaN  \
# 1                             6.215472                 NaN        NaN
# 2                             6.222971                 NaN        NaN
# 3                            10.482450                 NaN        NaN
# 4                            13.265852                 NaN        NaN
#
#    ACPC-1Cond_Sat_Ref_Pressure_Ckt1  ACPC-1ACC01_ACPC-1 EM.points.Exit temp.
# 0                               NaN                                      NaN  \
# 1                       1271.099976                                      NaN
# 2                       1265.099976                                      NaN
# 3                               NaN                                      NaN
# 4                        944.099976                                      NaN
#
#    ACPC-1Override_Enable  ACPC-1Evap_Ref_Pressure_Ckt1
# 0                    NaN                           NaN  \
# 1                    NaN                    364.799988
# 2                    NaN                    363.000000
# 3                    NaN                    421.799988
# 4                    NaN                    462.799988
#
#    ACPC-1Winding_Temp_#1_Motor_2A  ACPC-1Active_Demand_Limit_Setpoint
# 0                             NaN                               200.0  \
# 1                       35.740002                               200.0
# 2                       35.360001                               200.0
# 3                       29.459999                               200.0
# 4                       19.940001                               200.0
#
#    ACPC-1Diff_Ref_Pressure_Ckt1  ACPC-1Evap_Approach_ckt1
# 0                           NaN                       NaN  \
# 1                    906.900024                       NaN
# 2                    901.200012                       NaN
# 3                    562.500000                       NaN
# 4                    481.299988                       NaN
#
#    ACPC-1Chiller_Loading_Percent  ACPC-1Active_Chilled_Water_Setpoint
# 0                      52.685307                             7.325000  \
# 1                      55.795738                             7.250000
# 2                      55.953945                             7.255002
# 3                       0.000000                             7.440000
# 4                       0.000000                             7.429999
#
#    ACPC-1Cond_Sat_Ref_Temperature_Ckt2
# 0                                  NaN  \
# 1                            48.163933
# 2                            48.242470
# 3                            38.288887
# 4                            37.166763
#
#    ACPC-1Average_Motor_Current_%_RLA_AFD_2A  ACPC-1Evap_Ref_Pressure_Ckt2
# 0                                 81.500000                           NaN  \
# 1                                 81.300003                    366.100006
# 2                                 81.300003                    365.700012
# 3                                  0.000000                    420.299988
# 4                                  0.000000                    462.799988
#
#    ACPC-1NumericWritable  ACPC-1Evap_Sat_Ref_Temperature_Ckt2
# 0                    NaN                                  NaN  \
# 1               7.250000                             6.312960
# 2               7.255002                             6.342957
# 3               7.000000                            10.384963
# 4               7.429999                            13.272327
#
#    ACPC-1Diff_Ref_Pressure_Ckt2  ACPC-1Remote_Control-2
# 0                           NaN                     NaN  \
# 1                    894.000000                     NaN
# 2                    895.900024                     NaN
# 3                    552.299988                     NaN
# 4                    480.000000                     NaN
#
#    ACPC-1Evaporator_Entering_Water_Temperature  ACPC-1Oil_Pressure_Comp1A
# 0                                          NaN                        NaN  \
# 1                                        11.45                1240.699951
# 2                                        11.47                1235.400024
# 3                                        11.37                 426.799988
# 4                                        13.68                 468.000000
#
#    ACPC-1Average_Input_Current_AFD_1A  ACPC-1Winding_Temp_#2_Motor_2A
# 0                           59.400002                             NaN  \
# 1                           63.000000                       32.669998
# 2                           63.000000                       31.620001
# 3                            0.000000                       26.959999
# 4                            0.000000                       15.510000
#
#    ACPC-1MOV_CLose_Status  ACPC-1Master_Trip_Alarm
# 0                     NaN                      NaN  \
# 1                     NaN                      NaN
# 2                     NaN                      NaN
# 3                     NaN                      NaN
# 4                     NaN                      NaN
#
#    ACPC-1Outdoor_Air_Temperature  ACPC-1Cond_Sat_Ref_Pressure_Ckt2
# 0                            NaN                               NaN  \
# 1                      34.790001                       1260.000000
# 2                      34.500000                       1262.000000
# 3                      34.209999                        972.599976
# 4                      34.259998                        942.900024
#
#    ACPC-1Start_Stop_Control  ACPC-1Valve_Override_Enable
# 0                       NaN                          NaN  \
# 1                       NaN                          NaN
# 2                       NaN                          NaN
# 3                       NaN                          NaN
# 4                       NaN                          NaN
#
#    ACPC-1Evap_Approach_ckt2  ACPC-1Override_ON_OFF  ACPC-1efficiency
# ...
#
#    AHU-042Drivers.TrendIpNetwork.SHT-ECS-AHU-042 OS33.points.Sensor.SUPPLY AIR TEMP
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-042Drivers.TrendIpNetwork.SHT-ECS-AHU-042 OS33.points.Sensor.RETURN AIR TEMP
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-042Drivers.TrendIpNetwork.SHT-ECS-AHU-042 OS33.points.Sensor.MODULATING VALVE STATUS
# 0                                                NaN                                         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-042Drivers.TrendIpNetwork.SHT-ECS-AHU-042 OS33.points.DI.AHU ON OFF STATUS
# 0                                                NaN                               \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-045Drivers.TrendIpNetwork.SHT-ECS-AHU-045 OS37.points.Sensor.SUPPLY AIR TEMP
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-045Drivers.TrendIpNetwork.SHT-ECS-AHU-045 OS37.points.DI.AHU ON OFF STATUS
# 0                                                NaN                               \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-045Drivers.TrendIpNetwork.SHT-ECS-AHU-045 OS37.points.Sensor.RETURN AIR TEMP
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-045Drivers.TrendIpNetwork.SHT-ECS-AHU-045 OS37.points.Sensor.MODULATING VALVE STATUS
# 0                                                NaN                                         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-041Drivers.TrendIpNetwork.SHT-ECS-AHU-041 OS32.points.Sensor.RETURN AIR TEMP
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-041Drivers.TrendIpNetwork.SHT-ECS-AHU-041 OS32.points.Sensor.SUPPLY AIR TEMP
# 0                                                NaN                                 \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-041Drivers.TrendIpNetwork.SHT-ECS-AHU-041 OS32.points.Sensor.MODULATING VALVE STATUS
# 0                                                NaN                                         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    AHU-041Drivers.TrendIpNetwork.SHT-ECS-AHU-041 OS32.points.DI.AHU ON OFF STATUS
# 0                                                NaN                               \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    MOD-001&2Drivers.TrendIpNetwork.SHT-ECS-MOD-001&2 OS23.points.Sensor.OUTDOOR AIR TEMP
# 0                                                NaN                                      \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    MOD-001&2Drivers.TrendIpNetwork.SHT-ECS-MOD-001&2 OS23.points.DI.RETURN AIR DAMPER STATUS
# 0                                                NaN                                          \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    MOD-001&2Drivers.TrendIpNetwork.SHT-ECS-MOD-001&2 OS23.points.Sensor.OUTDOOR AIR RH
# 0                                                NaN                                    \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Test pointsconn_status_1  Test pointsconn_status_3
# 0                       NaN                       NaN  \
# 1                       NaN                       NaN
# 2                       NaN                       NaN
# 3                       NaN                       NaN
# 4                       NaN                       NaN
#
#    Test pointsconn_status_2  Chiller HeaderAdd_Chiller_SetPoint_T1
# 0                       NaN                                    NaN  \
# 1                       NaN                                    NaN
# 2                       NaN                                    NaN
# 3                       NaN                                    NaN
# 4                       NaN                                    NaN
#
#    Chiller HeaderBypass_Valve_Pressure_SetPoint
# 0                                           NaN  \
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    Chiller HeaderDemand_Deadband  Chiller HeaderMCWRT_Add_Setpoint
# 0                            NaN                               NaN  \
# 1                            NaN                               NaN
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                            NaN                               NaN
#
#    Chiller HeaderHeart_Beat  Chiller HeaderNos_of_ACC_Req
# 0                       NaN                           NaN  \
# 1                       NaN                           NaN
# 2                       NaN                           NaN
# 3                       NaN                           NaN
# 4                       NaN                           NaN
#
#    Chiller HeaderChiller_Bypass_Valve_Control
# 0                                         NaN  \
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Chiller HeaderF&E_Tank_High_Level_Alarm
# 0                                      NaN  \
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
#
#    Chiller HeaderBypass_Valve_Override_Enable
# 0                                         NaN  \
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Chiller HeaderF&E_Tank_Low_Level_Alarm
# 0                                     NaN  \
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#    Chiller HeaderAdd_Chiller_SetPoint_T2  Chiller HeaderMain_Supply_Temp
# 0                                    NaN                             NaN  \
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
#
#    Chiller HeaderCHWP_Pressure_Setpoint  Chiller HeaderMCWRT_Sub_Setpoint
# 0                                   NaN                               NaN  \
# 1                                   NaN                               NaN
# 2                                   NaN                               NaN
# 3                                   NaN                               NaN
# 4                                   NaN                               NaN
#
#    Chiller HeaderBypass_Valve_Remote_Control-2
# 0                                          NaN  \
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Chiller HeaderBypass_Valve_Override_SetPoint  Chiller HeaderDemand_Sepoint
# 0                                           NaN                           NaN  \
# 1                                           NaN                           NaN
# 2                                           NaN                           NaN
# 3                                           NaN                           NaN
# 4                                           NaN                           NaN
#
#    Chiller HeaderBypass_Valve_Remote_Control-1
# 0                                          NaN  \
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#    Chiller HeaderDrivers.BacnetNetwork.New Chiller Plant.points.Chiller Water Diff Pressure
# 0                                                NaN                                         \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Chiller HeaderSwitch_Temp_Reset  Chiller HeaderSwitch_Optimization
# 0                              NaN                                NaN  \
# 1                              NaN                                NaN
# 2                              NaN                                NaN
# 3                              NaN                                NaN
# 4                              NaN                                NaN
#
#    Chiller HeaderChiller Bypass Valve Postion
# 0                                         NaN  \
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#    Chiller HeaderChiller_Water_Diff_Pressure
# 0                                        NaN  \
# 1                                        NaN
# 2                                        NaN
# 3                                        NaN
# 4                                        NaN
#
#    Chiller HeaderChiller_Bypass_Valve_Postion  Chiller HeaderCHW_Temp_Diff
# 0                                         NaN                          NaN  \
# 1                                         NaN                          NaN
# 2                                         NaN                          NaN
# 3                                         NaN                          NaN
# 4                                         NaN                          NaN
#
#    Chiller HeaderMain_Return_Temp
# 0                             NaN  \
# 1                             NaN
# 2                             NaN
# 3                             NaN
# 4                             NaN
#
#    Chiller HeaderActive_Chilled_Water_Setpoint  Chiller HeaderFlow_Rate
# 0                                          NaN                      NaN  \
# 1                                          NaN                      NaN
# 2                                          NaN                      NaN
# 3                                          NaN                      NaN
# 4                                          NaN                      NaN
#
#    Chiller Headeron
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN

# %% [markdown]
# # Creating a column of the temperature difference

# %%
df['ACPC-1_T_Diff']=df['ACPC-1CHWR_Temp']-df['ACPC-1CHWS_Temp']
df['ACPC-2_T_Diff']=df['ACPC-2CHWR_Temp']-df['ACPC-2CHWS_Temp']
df['ACPC-3_T_Diff']=df['ACPC-3CHWR_Temp']-df['ACPC-3CHWS_Temp']
df['ACPC-4_T_Diff']=df['ACPC-4CHWR_Temp']-df['ACPC-4CHWS_Temp']

# %% [markdown]
# # We only consider the data when Comp_Power >10

# %%
df_power_on_ACPC1=df.loc[df['ACPC-1Comp_Power']>10]
df_power_on_ACPC2=df.loc[df['ACPC-2Comp_Power']>10]
df_power_on_ACPC3=df.loc[df['ACPC-3Comp_Power']>10]
df_power_on_ACPC4=df.loc[df['ACPC-4Comp_Power']>10]

# %% [markdown]
# Data overview of ACPC-1

# %%
df_power_on_ACPC1['ACPC-1_T_Diff'].describe()
# Out:
# count    2166.000000
# mean        2.468695
# std         0.757973
# min        -3.714115
# 25%         1.962260
# 50%         2.358469
# 75%         2.764104
# max         9.407415
# Name: ACPC-1_T_Diff, dtype: float64

# %% [markdown]
# # Some statistics of the Temperature Difference(The symptom)

# %% [markdown]
# ## Temperature difference distribution

# %%
fig, ax = plt.subplots()
N, bins, patches = ax.hist(df_power_on_ACPC1['ACPC-1_T_Diff'].values, edgecolor='white', linewidth=0.5,bins=[0,1, 2, 3, 4,5,6,7,8])
for i in range(0,3):
    patches[i].set_facecolor('b')
for i in range(3,len(patches)):    
    patches[i].set_facecolor('r')
plt.xlabel('Temperature difference')
plt.ylabel('Count')
plt.title('ACPC1 Temperature difference distribution')
plt.show()

fig, ax = plt.subplots()
N, bins, patches = ax.hist(df_power_on_ACPC2['ACPC-2_T_Diff'].values, edgecolor='white', linewidth=0.5,bins=[0,1, 2, 3, 4,5,6,7,8])
for i in range(0,3):
    patches[i].set_facecolor('b')
for i in range(3,len(patches)):    
    patches[i].set_facecolor('r')
plt.xlabel('Temperature difference')
plt.ylabel('Count')
plt.title('ACPC2 Temperature difference distribution')
plt.show()

fig, ax = plt.subplots()
N, bins, patches = ax.hist(df_power_on_ACPC3['ACPC-3_T_Diff'].values, edgecolor='white', linewidth=0.5,bins=[0,1, 2, 3, 4,5,6,7,8])
for i in range(0,3):
    patches[i].set_facecolor('b')
for i in range(3,len(patches)):    
    patches[i].set_facecolor('r')
plt.xlabel('Temperature difference')
plt.ylabel('Count')
plt.title('ACPC3 Temperature difference distribution')
plt.show()

fig, ax = plt.subplots()
N, bins, patches = ax.hist(df_power_on_ACPC4['ACPC-4_T_Diff'].values, edgecolor='white', linewidth=0.5,bins=[0,1, 2, 3, 4,5,6,7,8])
for i in range(0,3):
    patches[i].set_facecolor('b')
for i in range(3,len(patches)):    
    patches[i].set_facecolor('r')
plt.xlabel('Temperature difference')
plt.ylabel('Count')
plt.title('ACPC4 Temperature difference distribution')
plt.show()

# %% [markdown]
# ## Percentage of the symptom of each chiller

# %%
def mapfunction(diff):
    if diff < 3:
        return 'Small Delta'
    else:
        return 'Normal Delta'

# %%
df_power_on_ACPC1['cat']=df_power_on_ACPC1['ACPC-1_T_Diff'].map(mapfunction)
df_power_on_ACPC2['cat']=df_power_on_ACPC2['ACPC-2_T_Diff'].map(mapfunction)
df_power_on_ACPC3['cat']=df_power_on_ACPC3['ACPC-3_T_Diff'].map(mapfunction)
df_power_on_ACPC4['cat']=df_power_on_ACPC4['ACPC-4_T_Diff'].map(mapfunction)
# Out:
# <ipython-input-10-0870b70990ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_power_on_ACPC1['cat']=df_power_on_ACPC1['ACPC-1_T_Diff'].map(mapfunction)
# <ipython-input-10-0870b70990ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_power_on_ACPC2['cat']=df_power_on_ACPC2['ACPC-2_T_Diff'].map(mapfunction)
# <ipython-input-10-0870b70990ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_power_on_ACPC3['cat']=df_power_on_ACPC3['ACPC-3_T_Diff'].map(mapfunction)
# <ipython-input-10-0870b70990ea>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_power_on_ACPC4['cat']=df_power_on_ACPC4['ACPC-4_T_Diff'].map(mapfunction)

# %%
df_power_on_ACPC1['cat'].value_counts(dropna=False).plot(kind="pie",autopct='%1.1f%%')
plt.title('ACPC1 Temp Delta percentage')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
df_power_on_ACPC2['cat'].value_counts(dropna=False).plot(kind="pie",autopct='%1.1f%%')
plt.title('ACPC2 Temp Delta percentage')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
df_power_on_ACPC3['cat'].value_counts(dropna=False).plot(kind="pie",autopct='%1.1f%%')
plt.title('ACPC3 Temp Delta percentage')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %%
df_power_on_ACPC4['cat'].value_counts(dropna=False).plot(kind="pie",autopct='%1.1f%%')
plt.title('ACPC4 Temp Delta percentage')
plt.ylabel('Percentage')
# Out:
# Text(0, 0.5, 'Percentage')

# %% [markdown]
# # Temperature of the chillers over time

# %%
fig1, ax1 = plt.subplots(figsize=(12, 8))
df_1= df_power_on_ACPC1[['timestamp','ACPC-1_T_Diff','ACPC-1CHWS_Temp','ACPC-1CHWR_Temp']].dropna()
ACPC1_diff = df_1['ACPC-1_T_Diff'].values
df_1['date']=pd.to_datetime(df_1['timestamp'].values)
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=12))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax1.plot(df_1['date'].values, df_1['ACPC-1CHWS_Temp'].values)
ax1.plot(df_1['date'].values, df_1['ACPC-1CHWR_Temp'].values)
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature')
ax1.set_title('ACPC-1 Temp diff versu time')


fig1, ax2 = plt.subplots(figsize=(12, 8))
df_2= df_power_on_ACPC2[['timestamp','ACPC-2_T_Diff','ACPC-2CHWS_Temp','ACPC-2CHWR_Temp']].dropna()
ACPC2_diff = df_2['ACPC-2_T_Diff'].values
df_2['date']=pd.to_datetime(df_2['timestamp'].values)
ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=12))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax2.plot(df_2['date'].values, df_2['ACPC-2CHWS_Temp'].values)
ax2.plot(df_2['date'].values, df_2['ACPC-2CHWR_Temp'].values)
ax2.set_xlabel('Time')
ax2.set_ylabel('Temperature')
ax2.set_title('ACPC-2 Temp diff versu time')

fig1, ax2 = plt.subplots(figsize=(12, 8))
df_2= df_power_on_ACPC2[['timestamp','ACPC-2_T_Diff','ACPC-2CHWS_Temp','ACPC-2CHWR_Temp']].dropna()
ACPC2_diff = df_2['ACPC-2_T_Diff'].values
df_2['date']=pd.to_datetime(df_2['timestamp'].values)
ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=12))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax2.plot(df_2['date'].values, df_2['ACPC-2CHWS_Temp'].values)
ax2.plot(df_2['date'].values, df_2['ACPC-2CHWR_Temp'].values)
ax2.set_xlabel('Time')
ax2.set_ylabel('Temperature')
ax2.set_title('ACPC-2 Temp diff versu time')

fig1, ax3 = plt.subplots(figsize=(12, 8))
df_3= df_power_on_ACPC3[['timestamp','ACPC-3_T_Diff','ACPC-3CHWS_Temp','ACPC-3CHWR_Temp']].dropna()
ACPC3_diff = df_3['ACPC-3_T_Diff'].values
df_3['date']=pd.to_datetime(df_3['timestamp'].values)
ax3.xaxis.set_major_locator(mdates.MonthLocator(interval=12))
ax3.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax3.plot(df_3['date'].values, df_3['ACPC-3CHWS_Temp'].values)
ax3.plot(df_3['date'].values, df_3['ACPC-3CHWR_Temp'].values)
ax3.set_xlabel('Time')
ax3.set_ylabel('Temperature')
ax3.set_title('ACPC-3 Temp diff versu time')
plt.show()

# %%
threshold = 3

fig1, ax1 = plt.subplots(figsize=(14, 8))
df_1= df_power_on_ACPC1[['timestamp','ACPC-1_T_Diff']].dropna()
ACPC1_diff = df_1['ACPC-1_T_Diff'].values
colors_ACPC1 = np.where(ACPC1_diff<3,'b','r')
df_1['date']=pd.to_datetime(df_1['timestamp'].values)
ax1.plot(df_1['date'].values, df_1['ACPC-1_T_Diff'].values)
ax1.fill_between(x=df_1['date'].values, y1=threshold, color='orange',  interpolate=True, alpha=.75)
ax1.xaxis.set_major_locator(mdates.MonthLocator(interval=12))
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax1.set_xlabel('Time')
ax1.set_ylabel('Temperature difference')
ax1.set_title('ACPC-1 Temp diff versu time')
ax1.hlines(y=3,xmin=df_1['date'].values[0],xmax=df_1['date'].values[len(df_1['date'].values)-1],colors='yellow')


fig1, ax2 = plt.subplots(figsize=(14, 8))
df_2= df_power_on_ACPC2[['timestamp','ACPC-2_T_Diff']].dropna()
ACPC2_diff = df_2['ACPC-2_T_Diff'].values
df_2['date']=pd.to_datetime(df_2['timestamp'].values)
ax2.plot(df_2['date'].values, df_2['ACPC-2_T_Diff'].values)
ax2.fill_between(x=df_2['date'].values, y1=threshold, color='orange',  interpolate=True, alpha=.75)
ax2.xaxis.set_major_locator(mdates.MonthLocator(interval=12))
ax2.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax2.set_xlabel('Time')
ax2.set_ylabel('Temperature difference')
ax2.set_title('ACPC-2 Temp diff versu time')
ax2.hlines(y=3,xmin=df_2['date'].values[0],xmax=df_2['date'].values[len(df_2['date'].values)-1],colors='red')

fig1, ax3 = plt.subplots(figsize=(14, 8))
df_3= df_power_on_ACPC3[['timestamp','ACPC-3_T_Diff']].dropna()
ACPC3_diff = df_3['ACPC-3_T_Diff'].values
df_3['date']=pd.to_datetime(df_3['timestamp'].values)
ax3.plot(df_3['date'].values, df_3['ACPC-3_T_Diff'].values)
ax3.fill_between(x=df_3['date'].values, y1=threshold, color='orange',  interpolate=True, alpha=.75)
ax3.xaxis.set_major_locator(mdates.MonthLocator(interval=12))
ax3.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax3.set_xlabel('Time')
ax3.set_ylabel('Temperature difference')
ax3.set_title('ACPC-3 Temp diff versu time')
ax3.hlines(y=3,xmin=df_3['date'].values[0],xmax=df_3['date'].values[len(df_3['date'].values)-1],colors='red')

fig1, ax4 = plt.subplots(figsize=(14, 8))
df_4= df_power_on_ACPC4[['timestamp','ACPC-4_T_Diff']].dropna()
ACPC4_diff = df_4['ACPC-4_T_Diff'].values
df_4['date']=pd.to_datetime(df_4['timestamp'].values)
ax4.plot(df_4['date'].values, df_4['ACPC-4_T_Diff'].values)
ax4.fill_between(x=df_4['date'].values, y1=threshold, color='orange',  interpolate=True, alpha=.75)
ax4.xaxis.set_major_locator(mdates.MonthLocator(interval=12))
ax4.xaxis.set_major_formatter(mdates.DateFormatter('%b'))
ax4.set_xlabel('Time')
ax4.set_ylabel('Temperature difference')
ax4.set_title('ACPC-4 Temp diff versu time')
ax4.hlines(y=3,xmin=df_4['date'].values[0],xmax=df_4['date'].values[len(df_4['date'].values)-1],colors='red')

plt.show()

# %% [markdown]
# # Temperature Difference (The symptom) < 3 degree

# %%
avg_temp_diff_acpc1 = abs(df_power_on_ACPC1['ACPC-1_T_Diff'].mean())
avg_temp_diff_acpc2 = abs(df_power_on_ACPC2['ACPC-2_T_Diff'].mean())
avg_temp_diff_acpc3 = abs(df_power_on_ACPC3['ACPC-3_T_Diff'].mean())
avg_temp_diff_acpc4 = abs(df_power_on_ACPC4['ACPC-4_T_Diff'].mean())

# %%
Chillers = ['ACPC1','ACPC2','ACPC3','ACPC4']
temp_diff = [avg_temp_diff_acpc1,avg_temp_diff_acpc2,avg_temp_diff_acpc3,avg_temp_diff_acpc4]
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(Chillers, temp_diff, color ='maroon', 
        width = 0.4)
 
plt.xlabel("Courses offered")
plt.ylabel("No. of students enrolled")
plt.title("Students enrolled in different courses")
plt.show()

# %% [markdown]
# ## Flow Rate Visulization and correlation

# %%
avg_flow_rate_acpc1 = df_power_on_ACPC1['ACPC-1Flow_Rate'].mean()
avg_flow_rate_acpc2 = df_power_on_ACPC2['ACPC-2Flow_Rate'].mean()
avg_flow_rate_acpc3 = df_power_on_ACPC3['ACPC-3Flow_Rate'].mean()
avg_flow_rate_acpc4 = df_power_on_ACPC4['ACPC-4Flow_Rate'].mean()

# %%
Chillers = ['ACPC1','ACPC2','ACPC3','ACPC4']
flow_rate = [avg_flow_rate_acpc1,avg_flow_rate_acpc2,avg_flow_rate_acpc3,avg_flow_rate_acpc4]
  
bar_width = 0.35
index = np.arange(4)
fig, ax = plt.subplots(figsize = (10, 5))
summer = ax.bar(index, flow_rate, bar_width,
                label="flowrate")

winter = ax.bar(index+bar_width, temp_diff,
                 bar_width, label="tempdiff")

ax.set_xlabel('rate')
ax.set_ylabel('Incidence')
ax.set_title('Crime incidence by season, type')
ax.set_xticks(index + bar_width / 2)
ax.set_xticklabels(Chillers)
ax.legend()

plt.show()

# %%
dic_flow_rate = {Chillers[i]: flow_rate[i] for i in range(len(Chillers))}
dic_temp_diff = {Chillers[i]: temp_diff[i] for i in range(len(Chillers))}

# %%
data = {'flow_rate': flow_rate, 'temp_diff': temp_diff}
df_3 = pd.DataFrame.from_dict(data)

# %%
df_3.corr()
# Out:
#            flow_rate  temp_diff
# flow_rate   1.000000   0.998613
# temp_diff   0.998613   1.000000

# %%
sns.heatmap(df_3.corr(),cmap="Blues", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Flow rate is highly correlated to effectiveness of the chiller system
